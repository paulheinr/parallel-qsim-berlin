# %% [markdown]
# # Explorative Analysis
# I am using this notebook to explore the dataset of the Rust QSim and define some initial analysis figures.

# %%
# Importing necessary libraries
# import seaborn as sns

from pathlib import Path

# import file load.py
from load import discover_runs, load_run
# Out:
# Hello, World!

# %% [markdown]
# Now, let's discover the runs in the output directory and load them.

# %%
root = Path("/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4")

runs = discover_runs(root)
print(runs)
# Out:
# [RunMeta(run_id='sim128_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct'), sim_cpus=128, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim128_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct'), sim_cpus=128, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim16_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim16_hor600_w4_r192_10pct'), sim_cpus=16, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim16_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim16_hor600_w4_r192_1pct'), sim_cpus=16, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim192_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim192_hor600_w4_r192_10pct'), sim_cpus=192, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim192_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim192_hor600_w4_r192_1pct'), sim_cpus=192, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim1_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim1_hor600_w4_r192_10pct'), sim_cpus=1, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim1_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim1_hor600_w4_r192_1pct'), sim_cpus=1, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim2_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim2_hor600_w4_r192_10pct'), sim_cpus=2, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim2_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim2_hor600_w4_r192_1pct'), sim_cpus=2, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim32_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim32_hor600_w4_r192_10pct'), sim_cpus=32, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim32_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim32_hor600_w4_r192_1pct'), sim_cpus=32, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim4_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim4_hor600_w4_r192_10pct'), sim_cpus=4, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim4_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim4_hor600_w4_r192_1pct'), sim_cpus=4, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim64_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim64_hor600_w4_r192_10pct'), sim_cpus=64, horizon=600, worker_threads=4, router_threads=192, pct=10), RunMeta(run_id='sim64_hor600_w4_r192_1pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim64_hor600_w4_r192_1pct'), sim_cpus=64, horizon=600, worker_threads=4, router_threads=192, pct=1), RunMeta(run_id='sim8_hor600_w4_r192_10pct', path=PosixPath('/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim8_hor600_w4_r192_10pct'), sim_cpus=8, horizon=600, worker_threads=4 ...

# %%
data = {}
for run in runs:
    print(f"Loading run {run.run_id}")
    data[run.run_id] = load_run(run)
# Out:
# Loading run sim128_hor600_w4_r192_10pct
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_0.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_1.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_10.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_100.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_101.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_102.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_103.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_104.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_105.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_106.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_107.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_108.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_109.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_11.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_110.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_111.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_112.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_113.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_114.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_115.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_116.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_117.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_118.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_119.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_12.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_120.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_121.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_122.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_123.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_124.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_125.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_126.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_127.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_13.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_14.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_15.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_16.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_17.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_18.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_19.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_2.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_20.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_21.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_22.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_23.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_24.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_25.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_26.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_27.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_28.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_29.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_3.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_30.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_31.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_32.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_33.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_34.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_35.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_36.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_37.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_38.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_39.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_4.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_40.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_41.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_42.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_43.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_44.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_45.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_46.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_47.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_48.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_49.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_5.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_50.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_51.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_52.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_53.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_54.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_55.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_56.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_57.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_58.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_59.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_6.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_60.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_61.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_62.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_63.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_64.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_65.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_66.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_67.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_68.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_69.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_7.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_70.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_71.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_72.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_73.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_74.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_75.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_76.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_77.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_78.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_79.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_8.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_80.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_81.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_82.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_83.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_84.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_85.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_86.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_87.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_88.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_89.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_9.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_90.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_91.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_92.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_93.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_94.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_95.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_96.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_97.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_98.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_10pct/instrument/instrument_process_99.parquet
# Loading run sim128_hor600_w4_r192_1pct
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_0.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_1.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_10.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_100.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_101.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_102.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_103.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_104.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_105.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_106.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_107.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_108.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_109.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_11.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_110.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_111.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_112.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_113.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_114.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_115.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_116.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_117.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_118.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_119.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_12.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_120.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_121.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_122.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_123.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_124.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_125.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_126.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_127.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_13.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_14.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_15.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_16.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_17.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_18.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_19.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_2.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_20.parquet
# Reading instrument data from: /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/sim128_hor600_w4_r192_1pct/instrument/instrument_process_21.parquet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 for run in runs:
#       3     print(f"Loading run {run.run_id}")
# ----> 4     data[run.run_id] = load_run(run)
#
# File ~/git/parallel-qsim-berlin/src/main/python/load.py:196, in load_run(run, processes, include_source_path)
#     189 def load_run(
#     190         run: RunMeta,
#     191         processes: Optional[Iterable[int]] = None,
#     192         include_source_path: bool = False,
#     193 ) -> LoadRunResult:
#     194     # log loading
#     195     return LoadRunResult(
# --> 196         qsim=load_instrument(run, processes, include_source_path),
#     197         logic=load_routing(run, processes, include_source_path),
#     198     )
#
# File ~/git/parallel-qsim-berlin/src/main/python/load.py:129, in load_instrument(run, processes, include_source_path)
#     126 if proc_filter is not None and pid not in proc_filter:
#     127     continue
# --> 129 df = _read_parquet(path)
#     130 df = _convert_u128_column(df, "timestamp", "timestamp_u128")
#     132 df = _add_run_metadata(df, run, pid, path, include_source_path)
#
# File ~/git/parallel-qsim-berlin/src/main/python/load.py:92, in _read_parquet(path)
#      91 def _read_parquet(path: Path) -> pd.DataFrame:
# ---> 92     table = pq.read_table(path)
#      93     return table.to_pandas(types_mapper=None)
#
# File /opt/homebrew/anaconda3/envs/router/lib/python3.14/site-packages/pyarrow/parquet/core.py:1898, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1884     # TODO test that source is not a directory or a list
#    1885     dataset = ParquetFile(
#    1886         source, read_dictionary=read_dictionary,
#    1887         binary_type=binary_type,
#    (...)   1895         page_checksum_verification=page_checksum_verification,
#    1896     )
# -> 1898 return dataset.read(columns=columns, use_threads=use_threads,
#    1899                     use_pandas_metadata=use_pandas_metadata)
#
# File /opt/homebrew/anaconda3/envs/router/lib/python3.14/site-packages/pyarrow/parquet/core.py:1538, in ParquetDataset.read(self, columns, use_threads, use_pandas_metadata)
#    1530         index_columns = [
#    1531             col for col in _get_pandas_index_columns(metadata)
#    1532             if not isinstance(col, dict)
#    1533         ]
#    1534         columns = (
#    1535             list(columns) + list(set(index_columns) - set(columns))
#    1536         )
# -> 1538 table = self._dataset.to_table(
#    1539     columns=columns, filter=self._filter_expression,
#    1540     use_threads=use_threads
#    1541 )
#    1543 # if use_pandas_metadata, restore the pandas metadata (which gets
#    1544 # lost if doing a specific `columns` selection in to_table)
#    1545 if use_pandas_metadata:
#
# KeyboardInterrupt:
