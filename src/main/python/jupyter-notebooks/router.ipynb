# %%
# read csv file from /Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/10pct/routing-sim64_hor600_w4_r192_10pct

import pandas as pd
df = pd.read_csv("/Users/paulh/hlrn-cluster/rust-pt-routing/parallel-qsim-berlin/output/v6.4/10pct/routing-mock_routing24/88e082c/routing-profiling-2026-01-12_14-27-34.csv")
df.head()
# Out:
#    thread  now  departure_time         from             to           start  \
# 0       1    0               0  627608831#1     -4557344#2  14599388755472
# 1       5    0             214  -1101010197   -182600492#0  14599388756462
# 2       9    0               0     -8149650     -146174357  14599388754492
# 3      11    0               0  -34822334#0  -1122765058#0  14599388755552
# 4      12    0               0    -21603801        4689342  14599388754442
#
#    duration_ns  travel_time_s  request_id
# 0    101724721            971           0
# 1    101721331           1015           0
# 2    101728521           1042           0
# 3    101729131            343           0
# 4    101729141            467           0

# %%
# print statistics about duration_ns column
print((df['duration_ns']/1e6).describe())

# print 10, 20, 30, ... quantiles of duration_ns column in df
print((df['duration_ns']/1e6).quantile([r/10 for r in range(0,10)]))

#print distribution of duration_ns column with seaborn
import seaborn as sns
sns.displot(df['duration_ns']/1e6)
# add x axis label "Duration (ms)"
import matplotlib.pyplot as plt
plt.xlabel('Duration (ms)')
# Out:
# count    627191.000000
# mean          3.895273
# std           6.436764
# min           0.195750
# 25%           0.599045
# 50%           1.020775
# 75%           4.489916
# max         137.702349
# Name: duration_ns, dtype: float64
# 0.0     0.195750
# 0.1     0.436506
# 0.2     0.546429
# 0.3     0.654379
# 0.4     0.792295
# 0.5     1.020775
# 0.6     1.635076
# 0.7     3.276865
# 0.8     5.980223
# 0.9    10.979262
# Name: duration_ns, dtype: float64
# Text(0.5, 9.444444444444438, 'Duration (ms)')

# %%
# plot now on x axis and duration_ns on y axis
sns.lineplot(x=df.index, y=df['duration_ns']/1e6)
# add x axis label "Simulation Step"
plt.xlabel('Simulation Step')
# add y axis label "Duration (ms)"
plt.ylabel('Duration (ms)')
plt.yscale(value="log")
# add title "Routing Duration over Simulation Steps"
plt.title('Routing Duration over Simulation Steps')
# Out:
# Text(0.5, 1.0, 'Routing Duration over Simulation Steps')

# %%
ax = sns.histplot(
    data=df,
    x=df["now"],
    y=df["duration_ns"] / 1e6,
    bins=(1000, 1000),
    cbar=True,
    cbar_kws={"label": "Count"}
)

ax.set_yscale("log")
ax.set_ylabel("Duration (ms)")
# Out:
# Text(0, 0.5, 'Duration (ms)')

# %%
ax = sns.histplot(
    data=df,
    x=df["travel_time_s"],
    y=df["duration_ns"] / 1e6,
    # bins=(1000, 1000),
    cbar=True,
    cbar_kws={"label": "Count"}
)

ax.set_yscale("log")
ax.set_ylabel("Duration (ms)")
# Out:
# Text(0, 0.5, 'Duration (ms)')
